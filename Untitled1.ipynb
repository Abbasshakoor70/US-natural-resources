# %%
import pandas as pd
import matplotlib.pyplot as plt

# Loading the CSV file

revn = pd.read_csv('calendar_year_revenue.csv')

# Calendar Year and sum the revenue for each year

year_revn = revn.groupby('Calendar Year')['Revenue'].sum()

# line graph
plt.figure(figsize=(8, 4))
yearly_revenue.plot(kind='line', marker='o', color='r')
plt.title('Total Revenue by Calendar Year')
plt.xlabel('Year')
plt.ylabel('Revenue')
plt.grid(True)

# Display the plot
plt.show()

# %%
year_revn = revn.groupby('Calendar Year')['Revenue'].sum()
# Plot the bar chart
plt.figure(figsize=(10, 6))
revn.plot(kind='bar', color='black', edgecolor='red')

# Add titles and labels
plt.title('Total Revenue by Calendar Year')
plt.xlabel('Year')
plt.ylabel('Total Revenue')

# Add gridlines and rotate x-axis labels for readability

plt.grid(True, axis='y')
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
# Plot histogram for the 'Revenue' column
plt.figure(figsize=(10, 6))
plt.hist(revn['Revenue'], bins=3, color='blue', edgecolor='black')

# Add titles and labels to graph

plt.title('Revenue Distribution (Histogram)')
plt.xlabel('Revenue')
plt.ylabel('Frequency')

# Display the plot
plt.grid(True)
plt.show()
